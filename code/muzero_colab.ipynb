# %% [markdown]
# # Reproducing and Enhancing DeepMind’s MuZero
#
# ### Run this file in [Google Colab](https://colab.research.google.com/)

# %%
# !git clone https://github.com/madhusivaraj/muzero
# %cd muzero/code/
# !pip install -r requirements.txt
# !pip uninstall -y pyarrow
# %load_ext tensorboard

# %%
# %tensorboard --logdir ./results

# %%
# !python3 muzero.py
